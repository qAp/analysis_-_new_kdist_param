# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="28361226-bad2-449b-ad93-08b93200b771">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 2
MOLECULE = {'h2o': 'atmpro'}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band02 {'h2o': 'atmpro'}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=CLIENT.cliradnew.lw))
    dcli = pcli.modeldata_pymongo(collection=CLIENT.cliradnew.lw, commits=['1013f91', 'de5d43e'])
        
    plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_wgt_flux=1)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=CLIENT.lblnew.bestfit_lw))
    dlbl = plbl.modeldata_pymongo(collection=CLIENT.lblnew.bestfit_lw, commits=['a06b618', '5014a19'])
        
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [2] {'h2o': 'atmpro'} mls
#                           Run parameters  \
#                                   CLIRAD
# atmpro                 mls
# band                   [2]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                                              \
#                                                                                      LBLNEW
# atmpro                 mls
# band                   2
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [-2, -2, 0]
# ng_refs                [2, 3, 6]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [10, 250], [500, 250]]
# tsfc                   294
# vmax                   540
# vmin                   340
# w_diffuse              [[1.66, 1.66], [1.8, 1.8, 1.8], [1.8, 1.66, 1.45, 1.45, 1.45, 1.45]]
# wgt                    [[0.6, 0.6], [0.6, 0.6, 0.6], [0.6, 0.6, 0.6, 0.6, 0.6, 0.6]]
#
#                                                                              Fit parameters
#                                                                                    (h2o, 2)
# atmpro                 mls
# band                   2
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [-2, -2, 0]
# ng_refs                [2, 3, 6]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   540
# vmin                   340
# w_diffuse              [(1.66, 1.66), (1.8, 1.8, 1.8), (1.8, 1.66, 1.45, 1.45, 1.45, 1.45)]
# wgt                    [(0.6, 0.6), (0.6, 0.6, 0.6), (0.6, 0.6, 0.6, 0.6, 0.6, 0.6)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="672c7a00-a55d-4102-9c77-b86c83ff20fe"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.000    1     -60.3667  0.0000  -60.3667 -60.1396    0.0000  -60.1396
# 180.875  41    -60.4323  1.0063  -59.4260 -60.2111    0.9827  -59.2284
# 1013.000 76    -82.3158  81.2015 -1.1143  -82.3158    81.5536 -0.7622
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1     -60.0748  0.0000  -60.0748  0.2919       0.0000  0.2919
# 180.875  41    -60.1470  0.9893  -59.1577  0.2852      -0.0170  0.2683
# 1013.000 76    -82.3158  81.5764 -0.7394   0.0000       0.3749  0.3749
# _____
# -----------------------------
# #### [2] {'h2o': 'atmpro'} saw
#                           Run parameters  \
#                                   CLIRAD
# atmpro                 saw
# band                   [2]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                                              \
#                                                                                      LBLNEW
# atmpro                 saw
# band                   2
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [-2, -2, 0]
# ng_refs                [2, 3, 6]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  0
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [10, 250], [500, 250]]
# tsfc                   257
# vmax                   540
# vmin                   340
# w_diffuse              [[1.66, 1.66], [1.8, 1.8, 1.8], [1.8, 1.66, 1.45, 1.45, 1.45, 1.45]]
# wgt                    [[0.6, 0.6], [0.6, 0.6, 0.6], [0.6, 0.6, 0.6, 0.6, 0.6, 0.6]]
#
#                                                                              Fit parameters
#                                                                                    (h2o, 2)
# atmpro                 mls
# band                   2
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [-2, -2, 0]
# ng_refs                [2, 3, 6]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   540
# vmin                   340
# w_diffuse              [(1.66, 1.66), (1.8, 1.8, 1.8), (1.8, 1.66, 1.45, 1.45, 1.45, 1.45)]
# wgt                    [(0.6, 0.6), (0.6, 0.6, 0.6), (0.6, 0.6, 0.6, 0.6, 0.6, 0.6)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="407d138c-34c3-4411-b685-eabdcbd77ac8"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.00     1     -51.9373  0.0000  -51.9373 -51.8961    0.0000  -51.8961
# 299.75   46    -52.2339  2.6376  -49.5963 -52.1993    2.6038  -49.5955
# 1013.00  76    -58.1835  48.8958 -9.2877  -58.1835    48.6340 -9.5495
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -51.8633  0.0000  -51.8633  0.0741       0.0000  0.0741
# 299.75   46    -52.1681  2.6201  -49.5480  0.0658      -0.0175  0.0483
# 1013.00  76    -58.1835  48.7635 -9.4200  -0.0000      -0.1323 -0.1323
# _____
# -----------------------------
# #### [2] {'h2o': 'atmpro'} trp
#                           Run parameters  \
#                                   CLIRAD
# atmpro                 trp
# band                   [2]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                                              \
#                                                                                      LBLNEW
# atmpro                 trp
# band                   2
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [-2, -2, 0]
# ng_refs                [2, 3, 6]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  0
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [10, 250], [500, 250]]
# tsfc                   300
# vmax                   540
# vmin                   340
# w_diffuse              [[1.66, 1.66], [1.8, 1.8, 1.8], [1.8, 1.66, 1.45, 1.45, 1.45, 1.45]]
# wgt                    [[0.6, 0.6], [0.6, 0.6, 0.6], [0.6, 0.6, 0.6, 0.6, 0.6, 0.6]]
#
#                                                                              Fit parameters
#                                                                                    (h2o, 2)
# atmpro                 mls
# band                   2
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [-2, -2, 0]
# ng_refs                [2, 3, 6]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   540
# vmin                   340
# w_diffuse              [(1.66, 1.66), (1.8, 1.8, 1.8), (1.8, 1.66, 1.45, 1.45, 1.45, 1.45)]
# wgt                    [(0.6, 0.6), (0.6, 0.6, 0.6), (0.6, 0.6, 0.6, 0.6, 0.6, 0.6)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="4728cef8-48a8-48ff-9174-13b6baf2817c"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.00     1     -61.1958  0.0000  -61.1958 -60.9394    0.0000  -60.9394
# 109.55   38    -61.1927  0.4128  -60.7799 -60.9387    0.3849  -60.5538
# 1013.00  76    -86.4752  85.5841 -0.8912  -86.4752    85.8288 -0.6465
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -60.8734  0.0000  -60.8734  0.3224       0.0000  0.3224
# 109.55   38    -60.8728  0.3875  -60.4853  0.3199      -0.0253  0.2946
# 1013.00  76    -86.4752  85.8350 -0.6402   0.0000       0.2509  0.2509
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
