# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aa64a394-37a3-42a2-8b15-df1112802abe">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 6
MOLECULE = {'h2o':'atmpro', 'co2':400e-6}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
COLLEC_CLI = CLIENT.cliradnew.lw    
COLLEC_LBL = CLIENT.lblnew.bestfit_lw if len(MOLECULE) == 1 else CLIENT.lblnew.overlap_lw

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band06 {'h2o': 'atmpro', 'co2': 0.0004}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=COLLEC_CLI))
    dcli = pcli.modeldata_pymongo(collection=COLLEC_CLI, commits=['1013f91', 'de5d43e', '523cbb7'])
    
    if len(MOLECULE) == 1:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_flux_wgt=1)
    else:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=COLLEC_LBL))
    dlbl = plbl.modeldata_pymongo(collection=COLLEC_LBL, commits=['5014a19'])
        
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [6] {'co2': 0.0004, 'h2o': 'atmpro'} mls
#                                          Run parameters  \
#                                                  CLIRAD
# atmpro                 mls
# band                   [6]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                Fit parameters  \
#                                                  LBLNEW              (h2o, 4)
# atmpro                 mls                               mls
# band                   4                                 4
# commitnumber           5014a19                           a06b618
# conc                   -                                 -
# dv                     0.001                             0.001
# klin                   -                                 1e-24
# molecule               {'h2o': 'atmpro', 'co2': 0.0004}  h2o
# ng_adju                -                                 [0]
# ng_refs                -                                 [3]
# nv                     1000                              1000
# option_compute_btable  -                                 0
# option_compute_ktable  -                                 1
# option_wgt_flux        -                                 1
# option_wgt_k           -                                 1
# ref_pts                -                                 [(600, 250)]
# tsfc                   294                               294
# vmax                   -                                 980
# vmin                   -                                 800
# w_diffuse              -                                 [(1.66, 1.66, 1.85)]
# wgt                    -                                 [(0.5, 0.55, 0.85)]
#
#
#                                       (co2, 4)
# atmpro                 mls
# band                   4
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.5e-24
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [1, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   980
# vmin                   800
# w_diffuse              [(1.75,), (1.66, 1.9)]
# wgt                    [(0.75,), (0.75, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e046bb21-4b90-48ee-ad90-24080f7b322c"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.000    1     -60.0981  0.0000 -60.0981 -60.2058    0.0000 -60.2058 -60.1677
# 180.875  41    -60.1384  0.0196 -60.1189 -60.2440    0.0168 -60.2272 -60.2083
# 1013.000 76    -61.6812  8.7404 -52.9408 -61.6812    8.6270 -53.0543 -61.6812
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1      0.0000 -60.1677 -0.0696       0.0000 -0.0696
# 180.875  41     0.0179 -60.1905 -0.0699      -0.0017 -0.0716
# 1013.000 76     8.8172 -52.8641 -0.0000       0.0767  0.0767
# _____
# -----------------------------
# #### [6] {'co2': 0.0004, 'h2o': 'atmpro'} saw
#                                          Run parameters  \
#                                                  CLIRAD
# atmpro                 saw
# band                   [6]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                Fit parameters  \
#                                                  LBLNEW              (h2o, 4)
# atmpro                 saw                               mls
# band                   4                                 4
# commitnumber           5014a19                           a06b618
# conc                   -                                 -
# dv                     0.001                             0.001
# klin                   -                                 1e-24
# molecule               {'h2o': 'atmpro', 'co2': 0.0004}  h2o
# ng_adju                -                                 [0]
# ng_refs                -                                 [3]
# nv                     1000                              1000
# option_compute_btable  -                                 0
# option_compute_ktable  -                                 1
# option_wgt_flux        -                                 1
# option_wgt_k           -                                 1
# ref_pts                -                                 [(600, 250)]
# tsfc                   257                               294
# vmax                   -                                 980
# vmin                   -                                 800
# w_diffuse              -                                 [(1.66, 1.66, 1.85)]
# wgt                    -                                 [(0.5, 0.55, 0.85)]
#
#
#                                       (co2, 4)
# atmpro                 mls
# band                   4
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.5e-24
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [1, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   980
# vmin                   800
# w_diffuse              [(1.75,), (1.66, 1.9)]
# wgt                    [(0.75,), (0.75, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="69baf6f1-d2f5-4e6e-b26b-a27c960abb2b"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.00     1     -32.7477  0.0000 -32.7477 -32.7677    0.0000 -32.7677 -32.7625
# 299.75   46    -32.7796  0.0234 -32.7562 -32.7955    0.0197 -32.7758 -32.7919
# 1013.00  76    -32.8638  1.1598 -31.7039 -32.8638    1.0273 -31.8364 -32.8638
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1      0.0000 -32.7625 -0.0148       0.0000 -0.0148
# 299.75   46     0.0209 -32.7710 -0.0123      -0.0025 -0.0148
# 1013.00  76     1.0595 -31.8043 -0.0000      -0.1003 -0.1003
# _____
# -----------------------------
# #### [6] {'co2': 0.0004, 'h2o': 'atmpro'} trp
#                                          Run parameters  \
#                                                  CLIRAD
# atmpro                 trp
# band                   [6]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                Fit parameters  \
#                                                  LBLNEW              (h2o, 4)
# atmpro                 trp                               mls
# band                   4                                 4
# commitnumber           5014a19                           a06b618
# conc                   -                                 -
# dv                     0.001                             0.001
# klin                   -                                 1e-24
# molecule               {'h2o': 'atmpro', 'co2': 0.0004}  h2o
# ng_adju                -                                 [0]
# ng_refs                -                                 [3]
# nv                     1000                              1000
# option_compute_btable  -                                 0
# option_compute_ktable  -                                 1
# option_wgt_flux        -                                 1
# option_wgt_k           -                                 1
# ref_pts                -                                 [(600, 250)]
# tsfc                   300                               294
# vmax                   -                                 980
# vmin                   -                                 800
# w_diffuse              -                                 [(1.66, 1.66, 1.85)]
# wgt                    -                                 [(0.5, 0.55, 0.85)]
#
#
#                                       (co2, 4)
# atmpro                 mls
# band                   4
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.5e-24
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [1, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   980
# vmin                   800
# w_diffuse              [(1.75,), (1.66, 1.9)]
# wgt                    [(0.75,), (0.75, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ae97e7d2-f4b5-4d9b-bdb3-864b24b99312"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.00     1     -64.9840  0.0000  -64.9840 -65.0741    0.0000  -65.0741
# 109.55   38    -65.0040  0.0098  -64.9942 -65.0936    0.0084  -65.0851
# 1013.00  76    -67.3494  11.6254 -55.7240 -67.3494    11.8774 -55.4721
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -65.0225  0.0000  -65.0225 -0.0385       0.0000 -0.0385
# 109.55   38    -65.0431  0.0089  -65.0342 -0.0391      -0.0009 -0.0400
# 1013.00  76    -67.3494  12.0799 -55.2695  0.0000       0.4545  0.4545
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
