# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e640728b-36c9-49df-ba11-cc84d1f9c67e">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 5
MOLECULE = {'h2o':'atmpro', 'co2':400e-6}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
COLLEC_CLI = CLIENT.cliradnew.lw    
COLLEC_LBL = CLIENT.lblnew.bestfit_lw if len(MOLECULE) == 1 else CLIENT.lblnew.overlap_lw

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band05 {'h2o': 'atmpro', 'co2': 0.0004}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=COLLEC_CLI))
    dcli = pcli.modeldata_pymongo(collection=COLLEC_CLI, commits=['1013f91', 'de5d43e', '523cbb7'])
    
    if len(MOLECULE) == 1:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_flux_wgt=1)
    else:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=COLLEC_LBL))
    dlbl = plbl.modeldata_pymongo(collection=COLLEC_LBL, commits=['5014a19'])
        
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [5] {'co2': 0.0004, 'h2o': 'atmpro'} mls
#                                          Run parameters  \
#                                                  CLIRAD
# atmpro                 mls
# band                   [5]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                          \
#                                                  LBLNEW
# atmpro                 mls
# band                   3c
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'co2': 0.0004}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                        Fit parameters  \
#                                             (h2o, 3c)
# atmpro                 mls
# band                   3c
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   5e-25
# molecule               h2o
# ng_adju                [0]
# ng_refs                [5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(600, 250)]
# tsfc                   294
# vmax                   800
# vmin                   720
# w_diffuse              [(1.55, 1.6, 1.66, 1.66, 1.8)]
# wgt                    [(0.5, 0.5, 0.6, 0.7, 0.9)]
#
#
#                                                                   (co2, 3c)
# atmpro                 mls
# band                   3c
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.37556e-24
# molecule               co2
# ng_adju                [0, 0, 0]
# ng_refs                [3, 2, 4]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   800
# vmin                   720
# w_diffuse              [(1.7, 1.6, 1.8), (1.8, 1.7), (1.5, 1.6, 1.7, 1.8)]
# wgt                    [(0.6, 0.4, 0.7), (0.7, 0.4), (0.3, 0.4, 0.85, 0.9)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c2510a1f-74cb-48a2-9d77-f095543dfb65"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.000    1     -24.8942  0.0000  -24.8942 -24.6935    0.0000  -24.6935
# 180.875  41    -25.2225  0.9128  -24.3097 -25.0256    0.8953  -24.1303
# 1013.000 76    -32.6375  20.8541 -11.7835 -32.6375    21.2379 -11.3997
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1     -24.6379  0.0000  -24.6379  0.2562       0.0000  0.2562
# 180.875  41    -24.9766  0.9035  -24.0731  0.2459      -0.0093  0.2366
# 1013.000 76    -32.6375  21.3516 -11.2859  0.0000       0.4975  0.4975
# _____
# -----------------------------
# #### [5] {'co2': 0.0004, 'h2o': 'atmpro'} saw
#                                          Run parameters  \
#                                                  CLIRAD
# atmpro                 saw
# band                   [5]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                          \
#                                                  LBLNEW
# atmpro                 saw
# band                   3c
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'co2': 0.0004}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                        Fit parameters  \
#                                             (h2o, 3c)
# atmpro                 mls
# band                   3c
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   5e-25
# molecule               h2o
# ng_adju                [0]
# ng_refs                [5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(600, 250)]
# tsfc                   294
# vmax                   800
# vmin                   720
# w_diffuse              [(1.55, 1.6, 1.66, 1.66, 1.8)]
# wgt                    [(0.5, 0.5, 0.6, 0.7, 0.9)]
#
#
#                                                                   (co2, 3c)
# atmpro                 mls
# band                   3c
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.37556e-24
# molecule               co2
# ng_adju                [0, 0, 0]
# ng_refs                [3, 2, 4]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   800
# vmin                   720
# w_diffuse              [(1.7, 1.6, 1.8), (1.8, 1.7), (1.5, 1.6, 1.7, 1.8)]
# wgt                    [(0.6, 0.4, 0.7), (0.7, 0.4), (0.3, 0.4, 0.85, 0.9)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="9dcb08d4-12db-42ae-aa71-d01b709a5abc"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.00     1     -16.3375  0.0000 -16.3375 -16.2666    0.0000 -16.2666 -16.2418
# 299.75   46    -16.8535  1.3344 -15.5191 -16.7990    1.3507 -15.4483 -16.7802
# 1013.00  76    -18.9215  9.1920 -9.7296  -18.9215    9.3187 -9.6029  -18.9215
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1      0.0000 -16.2418  0.0956       0.0000  0.0956
# 299.75   46     1.3621 -15.4180  0.0734       0.0277  0.1011
# 1013.00  76     9.3822 -9.5394   0.0000       0.1902  0.1902
# _____
# -----------------------------
# #### [5] {'co2': 0.0004, 'h2o': 'atmpro'} trp
#                                          Run parameters  \
#                                                  CLIRAD
# atmpro                 trp
# band                   [5]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                          \
#                                                  LBLNEW
# atmpro                 trp
# band                   3c
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'co2': 0.0004}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                        Fit parameters  \
#                                             (h2o, 3c)
# atmpro                 mls
# band                   3c
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   5e-25
# molecule               h2o
# ng_adju                [0]
# ng_refs                [5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(600, 250)]
# tsfc                   294
# vmax                   800
# vmin                   720
# w_diffuse              [(1.55, 1.6, 1.66, 1.66, 1.8)]
# wgt                    [(0.5, 0.5, 0.6, 0.7, 0.9)]
#
#
#                                                                   (co2, 3c)
# atmpro                 mls
# band                   3c
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.37556e-24
# molecule               co2
# ng_adju                [0, 0, 0]
# ng_refs                [3, 2, 4]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   800
# vmin                   720
# w_diffuse              [(1.7, 1.6, 1.8), (1.8, 1.7), (1.5, 1.6, 1.7, 1.8)]
# wgt                    [(0.6, 0.4, 0.7), (0.7, 0.4), (0.3, 0.4, 0.85, 0.9)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ead4ef0d-de33-4fab-a223-07f3fe52fcc5"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.00     1     -26.0074  0.0000  -26.0074 -25.7561    0.0000  -25.7561
# 109.55   38    -26.0316  0.4099  -25.6217 -25.7585    0.3726  -25.3859
# 1013.00  76    -35.2235  23.5549 -11.6687 -35.2235    24.0566 -11.1669
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -25.6923  0.0000  -25.6923  0.3151       0.0000  0.3151
# 109.55   38    -25.6974  0.3766  -25.3208  0.3341      -0.0333  0.3009
# 1013.00  76    -35.2235  24.1598 -11.0638 -0.0000       0.6049  0.6049
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
