# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a12148be-c85e-48c1-9143-e1c0b1512924">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 9
MOLECULE = {'h2o':'atmpro', 'n2o':3.2e-07, 'ch4':1.8e-06}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band09 {'h2o': 'atmpro', 'n2o': 3.2e-07, 'ch4': 1.8e-06}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=CLIENT.cliradnew.lw))
    dcli = pcli.modeldata_pymongo(collection=CLIENT.cliradnew.lw, commits=['1013f91', 'de5d43e', '523cbb7'])
        
    plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=CLIENT.lblnew.overlap_lw))
    dlbl = plbl.modeldata_pymongo(collection=CLIENT.lblnew.overlap_lw, commits=['5014a19'])
        
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [9] {'ch4': 1.8e-06, 'h2o': 'atmpro', 'n2o': 3.2e-07} mls
#                                                           Run parameters  \
#                                                                   CLIRAD
# atmpro                 mls
# band                   [9]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'ch4': 1.8e-06, 'h2o': 'atmpro', 'n2o': 3.2e-07}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                           \
#                                                                   LBLNEW
# atmpro                 mls
# band                   7
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'n2o': 3.2e-07, 'ch4': 1.8e-06}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                               Fit parameters  \
#                                                     (h2o, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0]
# ng_refs                [7]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(600, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(2, 1.6, 1.6, 1.6, 1.6, 1.6, 1.8)]
# wgt                    [(0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.9)]
#
#                                                   \
#                                         (n2o, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [2, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(1.8, 1.66), (1.6, 1.8)]
# wgt                    [(0.6, 0.5), (0.6, 0.9)]
#
#
#                                                  (ch4, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   1.8e-06
# dv                     0.001
# klin                   2e-21
# molecule               ch4
# ng_adju                [0, 0]
# ng_refs                [2, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(1.66, 1.66), (1.66, 1.66, 1.66)]
# wgt                    [(0.7, 0.7), (0.4, 0.6, 0.75)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="48195e2a-fad6-4589-864a-dafb93fe2bf8"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.000    1     -12.5006  0.0000  -12.5006 -12.5357    0.0000  -12.5357
# 180.875  41    -12.8799  0.3277  -12.5522 -13.0475    0.3514  -12.6961
# 1013.000 76    -23.7552  19.9501 -3.8051  -23.7552    20.0915 -3.6637
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1     -12.5174  0.0000  -12.5174 -0.0168       0.0000 -0.0168
# 180.875  41    -13.0299  0.3516  -12.6783 -0.1500       0.0239 -0.1261
# 1013.000 76    -23.7552  20.1209 -3.6343  -0.0000       0.1709  0.1709
# _____
# -----------------------------
# #### [9] {'ch4': 1.8e-06, 'h2o': 'atmpro', 'n2o': 3.2e-07} saw
#                                                           Run parameters  \
#                                                                   CLIRAD
# atmpro                 saw
# band                   [9]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'ch4': 1.8e-06, 'h2o': 'atmpro', 'n2o': 3.2e-07}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                           \
#                                                                   LBLNEW
# atmpro                 saw
# band                   7
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'n2o': 3.2e-07, 'ch4': 1.8e-06}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                               Fit parameters  \
#                                                     (h2o, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0]
# ng_refs                [7]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(600, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(2, 1.6, 1.6, 1.6, 1.6, 1.6, 1.8)]
# wgt                    [(0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.9)]
#
#                                                   \
#                                         (n2o, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [2, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(1.8, 1.66), (1.6, 1.8)]
# wgt                    [(0.6, 0.5), (0.6, 0.9)]
#
#
#                                                  (ch4, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   1.8e-06
# dv                     0.001
# klin                   2e-21
# molecule               ch4
# ng_adju                [0, 0]
# ng_refs                [2, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(1.66, 1.66), (1.66, 1.66, 1.66)]
# wgt                    [(0.7, 0.7), (0.4, 0.6, 0.75)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="43db51ea-f6f4-48af-8295-0a1e56b0710f"></div>
# </div>
#                    CRD                 WGT igg=10                  CLIRAD  \
#                   flug    fldg   fnetg       flug    fldg   fnetg    flug
# pressure level
# 0.00     1     -6.8873  0.0000 -6.8873 -6.8593     0.0000 -6.8593 -6.8549
# 299.75   46    -7.3522  0.5061 -6.8461 -7.4326     0.5425 -6.8902 -7.4291
# 1013.00  76    -9.5580  6.6059 -2.9521 -9.5580     6.6160 -2.9420 -9.5580
#
#                                CLIRAD - CRD
#                   fldg   fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1      0.0000 -6.8549  0.0324       0.0000  0.0324
# 299.75   46     0.5429 -6.8862 -0.0769       0.0368 -0.0401
# 1013.00  76     6.6241 -2.9339  0.0000       0.0182  0.0182
# _____
# -----------------------------
# #### [9] {'ch4': 1.8e-06, 'h2o': 'atmpro', 'n2o': 3.2e-07} trp
#                                                           Run parameters  \
#                                                                   CLIRAD
# atmpro                 trp
# band                   [9]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'ch4': 1.8e-06, 'h2o': 'atmpro', 'n2o': 3.2e-07}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                           \
#                                                                   LBLNEW
# atmpro                 trp
# band                   7
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'n2o': 3.2e-07, 'ch4': 1.8e-06}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                               Fit parameters  \
#                                                     (h2o, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0]
# ng_refs                [7]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(600, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(2, 1.6, 1.6, 1.6, 1.6, 1.6, 1.8)]
# wgt                    [(0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.9)]
#
#                                                   \
#                                         (n2o, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [2, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(1.8, 1.66), (1.6, 1.8)]
# wgt                    [(0.6, 0.5), (0.6, 0.9)]
#
#
#                                                  (ch4, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   1.8e-06
# dv                     0.001
# klin                   2e-21
# molecule               ch4
# ng_adju                [0, 0]
# ng_refs                [2, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(1.66, 1.66), (1.66, 1.66, 1.66)]
# wgt                    [(0.7, 0.7), (0.4, 0.6, 0.75)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c64b84d5-7970-4775-9066-13b39a13453b"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.00     1     -13.1049  0.0000  -13.1049 -13.0995    0.0000  -13.0995
# 109.55   38    -13.2254  0.1271  -13.0983 -13.2955    0.1387  -13.1568
# 1013.00  76    -26.9627  23.1896 -3.7731  -26.9627    23.4408 -3.5220
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -13.0782  0.0000  -13.0782  0.0267       0.0000  0.0267
# 109.55   38    -13.2747  0.1389  -13.1359 -0.0494       0.0118 -0.0376
# 1013.00  76    -26.9628  23.4679 -3.4948  -0.0000       0.2783  0.2783
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
