# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b84b9f38-d439-4079-b457-a9d1564a6bad">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 9
MOLECULE = {'n2o':3.2e-7}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
COLLEC_CLI = CLIENT.cliradnew.lw    
COLLEC_LBL = CLIENT.lblnew.bestfit_lw if len(MOLECULE) == 1 else CLIENT.lblnew.overlap_lw

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band09 {'n2o': 3.2e-07}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=COLLEC_CLI))
    dcli = pcli.modeldata_pymongo(collection=COLLEC_CLI, commits=['1013f91', 'de5d43e', '523cbb7'])
    
    if len(MOLECULE) == 1:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_wgt_flux=1)
    else:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=COLLEC_LBL))
    dlbl = plbl.modeldata_pymongo(collection=COLLEC_LBL, commits=['a22ab94', 'a06b618', '5014a19'])
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [9] {'n2o': 3.2e-07} mls
#                          Run parameters                             \
#                                  CLIRAD                     LBLNEW
# atmpro                 mls               mls
# band                   [9]               7
# commitnumber           1013f91           a06b618
# conc                   -                 3.2e-07
# dv                     -                 0.001
# klin                   -                 2.22e-20
# molecule               {'n2o': 3.2e-07}  n2o
# ng_adju                -                 [0, 0]
# ng_refs                -                 [2, 2]
# nv                     -                 1000
# option_compute_btable  -                 0
# option_compute_ktable  -                 1
# option_wgt_flux        -                 1
# option_wgt_k           -                 1
# ref_pts                -                 [[1, 250], [500, 250]]
# tsfc                   294               294
# vmax                   -                 1380
# vmin                   -                 1215
# w_diffuse              -                 [[1.8, 1.66], [1.6, 1.8]]
# wgt                    -                 [[0.6, 0.5], [0.6, 0.9]]
#
#                                   Fit parameters
#                                         (n2o, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [2, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(1.8, 1.66), (1.6, 1.8)]
# wgt                    [(0.6, 0.5), (0.6, 0.9)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="173656fd-293c-4b51-97f7-410abef7d36c"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.000    1     -20.8732  0.0000 -20.8732 -20.6985    0.0000 -20.6985 -20.6971
# 180.875  41    -21.1588  0.1213 -21.0375 -21.1123    0.1157 -20.9966 -21.1119
# 1013.000 76    -23.7552  3.8773 -19.8779 -23.7552    3.8456 -19.9096 -23.7552
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1      0.0000 -20.6971  0.1761       0.0000  0.1761
# 180.875  41     0.1158 -20.9961  0.0469      -0.0056  0.0414
# 1013.000 76     3.8443 -19.9109 -0.0000      -0.0330 -0.0330
# _____
# -----------------------------
# #### [9] {'n2o': 3.2e-07} saw
#                          Run parameters                             \
#                                  CLIRAD                     LBLNEW
# atmpro                 saw               saw
# band                   [9]               7
# commitnumber           1013f91           5014a19
# conc                   -                 3.2e-07
# dv                     -                 0.001
# klin                   -                 2.22e-20
# molecule               {'n2o': 3.2e-07}  n2o
# ng_adju                -                 [0, 0]
# ng_refs                -                 [2, 2]
# nv                     -                 1000
# option_compute_btable  -                 0
# option_compute_ktable  -                 0
# option_wgt_flux        -                 1
# option_wgt_k           -                 1
# ref_pts                -                 [[1, 250], [500, 250]]
# tsfc                   257               257
# vmax                   -                 1380
# vmin                   -                 1215
# w_diffuse              -                 [[1.8, 1.66], [1.6, 1.8]]
# wgt                    -                 [[0.6, 0.5], [0.6, 0.9]]
#
#                                   Fit parameters
#                                         (n2o, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [2, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(1.8, 1.66), (1.6, 1.8)]
# wgt                    [(0.6, 0.5), (0.6, 0.9)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="f672b8ae-b1c9-464f-bc04-820b09a22323"></div>
# </div>
#                    CRD                 WGT igg=10                  CLIRAD  \
#                   flug    fldg   fnetg       flug    fldg   fnetg    flug
# pressure level
# 0.00     1     -8.6787  0.0000 -8.6787 -8.6303     0.0000 -8.6303 -8.6297
# 299.75   46    -8.9373  0.1907 -8.7467 -8.9819     0.1885 -8.7934 -8.9819
# 1013.00  76    -9.5580  1.8065 -7.7515 -9.5580     1.8318 -7.7262 -9.5580
#
#                                CLIRAD - CRD
#                   fldg   fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1      0.0000 -8.6297  0.0490       0.0000  0.0490
# 299.75   46     0.1887 -8.7932 -0.0445      -0.0020 -0.0466
# 1013.00  76     1.8314 -7.7267  0.0000       0.0248  0.0248
# _____
# -----------------------------
# #### [9] {'n2o': 3.2e-07} trp
#                          Run parameters                             \
#                                  CLIRAD                     LBLNEW
# atmpro                 trp               trp
# band                   [9]               7
# commitnumber           1013f91           5014a19
# conc                   -                 3.2e-07
# dv                     -                 0.001
# klin                   -                 2.22e-20
# molecule               {'n2o': 3.2e-07}  n2o
# ng_adju                -                 [0, 0]
# ng_refs                -                 [2, 2]
# nv                     -                 1000
# option_compute_btable  -                 0
# option_compute_ktable  -                 0
# option_wgt_flux        -                 1
# option_wgt_k           -                 1
# ref_pts                -                 [[1, 250], [500, 250]]
# tsfc                   300               300
# vmax                   -                 1380
# vmin                   -                 1215
# w_diffuse              -                 [[1.8, 1.66], [1.6, 1.8]]
# wgt                    -                 [[0.6, 0.5], [0.6, 0.9]]
#
#                                   Fit parameters
#                                         (n2o, 7)
# atmpro                 mls
# band                   7
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [2, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   1380
# vmin                   1215
# w_diffuse              [(1.8, 1.66), (1.6, 1.8)]
# wgt                    [(0.6, 0.5), (0.6, 0.9)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c71099ac-8a36-4d26-abf0-e62bdd5a1480"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.00     1     -23.5244  0.0000 -23.5244 -23.3046    0.0000 -23.3046 -23.3031
# 109.55   38    -23.6503  0.0469 -23.6034 -23.5038    0.0463 -23.4575 -23.5029
# 1013.00  76    -26.9627  4.2537 -22.7090 -26.9627    4.2002 -22.7625 -26.9628
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1      0.0000 -23.3031  0.2212       0.0000  0.2213
# 109.55   38     0.0463 -23.4567  0.1474      -0.0007  0.1467
# 1013.00  76     4.1988 -22.7639 -0.0000      -0.0549 -0.0549
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
