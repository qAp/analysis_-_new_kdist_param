# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="33d24f60-38df-4867-81d4-53f705bf1778">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 4
MOLECULE = {'co2':400e-6}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
COLLEC_CLI = CLIENT.cliradnew.lw    
COLLEC_LBL = CLIENT.lblnew.bestfit_lw if len(MOLECULE) == 1 else CLIENT.lblnew.overlap_lw

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band04 {'co2': 0.0004}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=COLLEC_CLI))
    dcli = pcli.modeldata_pymongo(collection=COLLEC_CLI, commits=['1013f91', 'de5d43e', '523cbb7'])
    
    if len(MOLECULE) == 1:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_wgt_flux=1)
    else:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=COLLEC_LBL))
    dlbl = plbl.modeldata_pymongo(collection=COLLEC_LBL, commits=['a22ab94', 'a06b618'])
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [4] {'co2': 0.0004} mls
#                         Run parameters  \
#                                 CLIRAD
# atmpro                 mls
# band                   [4]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                        \
#                                                                LBLNEW
# atmpro                 mls
# band                   3b
# commitnumber           a22ab94
# conc                   0.0004
# dv                     0.001
# klin                   0
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [5, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  0
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [10, 250]]
# tsfc                   294
# vmax                   720
# vmin                   620
# w_diffuse              [[1.66, 1.66, 1.66, 1.66, 1.66], [1.66, 1.66]]
# wgt                    [[0, 0.6, 0.5, 0.7, 0.8], [0.8, 0.7]]
#
#                                                                    Fit parameters
#                                                                         (co2, 3b)
# atmpro                 mls
# band                   3b
# commitnumber           a22ab94
# conc                   0.0004
# dv                     0.001
# klin                   0
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [5, 4]
# nv                     1000
# option_compute_btable  1
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250)]
# tsfc                   294
# vmax                   720
# vmin                   620
# w_diffuse              [(1.66, 1.66, 1.66, 1.66, 1.66), (1.66, 1.66, 1.66, 1.66)]
# wgt                    [(0, 0.5, 0.4, 0.6, 0.65), (0.7, 0.7, 0.55, 0.6)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7f61e4e5-aae9-48db-97ef-872043129fb0"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.000    1     -17.7793  0.0000  -17.7793 -17.4595    0.0000  -17.4595
# 180.875  41    -16.3529  10.6575 -5.6953  -15.7507    11.2434 -4.5073
# 1013.000 76    -43.9648  43.5348 -0.4300  -43.9648    43.6712 -0.2936
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1     -17.4691 -0.0000  -17.4691  0.3102      -0.0000  0.3102
# 180.875  41    -16.0971  10.8783 -5.2188   0.2557       0.2207  0.4765
# 1013.000 76    -43.9648  43.6313 -0.3335  -0.0000       0.0965  0.0965
# _____
# -----------------------------
# #### [4] {'co2': 0.0004} saw
#                         Run parameters  \
#                                 CLIRAD
# atmpro                 saw
# band                   [4]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                        \
#                                                                LBLNEW
# atmpro                 saw
# band                   3b
# commitnumber           a22ab94
# conc                   0.0004
# dv                     0.001
# klin                   0
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [5, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  0
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [10, 250]]
# tsfc                   257
# vmax                   720
# vmin                   620
# w_diffuse              [[1.66, 1.66, 1.66, 1.66, 1.66], [1.66, 1.66]]
# wgt                    [[0, 0.6, 0.5, 0.7, 0.8], [0.8, 0.7]]
#
#                                                                    Fit parameters
#                                                                         (co2, 3b)
# atmpro                 mls
# band                   3b
# commitnumber           a22ab94
# conc                   0.0004
# dv                     0.001
# klin                   0
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [5, 4]
# nv                     1000
# option_compute_btable  1
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250)]
# tsfc                   294
# vmax                   720
# vmin                   620
# w_diffuse              [(1.66, 1.66, 1.66, 1.66, 1.66), (1.66, 1.66, 1.66, 1.66)]
# wgt                    [(0, 0.5, 0.4, 0.6, 0.65), (0.7, 0.7, 0.55, 0.6)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ae871a39-4ab9-45dc-bcf6-3a1fa95d2b6f"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.00     1     -14.2904  0.0000  -14.2904 -14.0334    0.0000  -14.0334
# 299.75   46    -15.0177  11.9504 -3.0673  -14.6763    12.1479 -2.5284
# 1013.00  76    -27.0372  27.1144  0.0772  -27.0372    27.2240  0.1868
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -14.1453 -0.0000  -14.1453  0.145       -0.0000  0.1450
# 299.75   46    -14.8358  12.2725 -2.5632   0.182        0.3221  0.5041
# 1013.00  76    -27.0372  27.2020  0.1647  -0.000        0.0876  0.0876
# _____
# -----------------------------
# #### [4] {'co2': 0.0004} trp
#                         Run parameters  \
#                                 CLIRAD
# atmpro                 trp
# band                   [4]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                        \
#                                                                LBLNEW
# atmpro                 trp
# band                   3b
# commitnumber           a22ab94
# conc                   0.0004
# dv                     0.001
# klin                   0
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [5, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  0
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [10, 250]]
# tsfc                   300
# vmax                   720
# vmin                   620
# w_diffuse              [[1.66, 1.66, 1.66, 1.66, 1.66], [1.66, 1.66]]
# wgt                    [[0, 0.6, 0.5, 0.7, 0.8], [0.8, 0.7]]
#
#                                                                    Fit parameters
#                                                                         (co2, 3b)
# atmpro                 mls
# band                   3b
# commitnumber           a22ab94
# conc                   0.0004
# dv                     0.001
# klin                   0
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [5, 4]
# nv                     1000
# option_compute_btable  1
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250)]
# tsfc                   294
# vmax                   720
# vmin                   620
# w_diffuse              [(1.66, 1.66, 1.66, 1.66, 1.66), (1.66, 1.66, 1.66, 1.66)]
# wgt                    [(0, 0.5, 0.4, 0.6, 0.65), (0.7, 0.7, 0.55, 0.6)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1bf2d2f1-bbdd-47bc-935b-607fcb42f2a7"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.00     1     -16.2541  0.0000  -16.2541 -15.6709    0.0000  -15.6709
# 109.55   38    -12.8628  6.1549  -6.7079  -11.9415    6.8189  -5.1226
# 1013.00  76    -47.0675  46.4713 -0.5962  -47.0675    46.6188 -0.4487
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -15.8360 -0.0000  -15.8360  0.4181      -0.0000  0.4181
# 109.55   38    -12.4310  6.1815  -6.2495   0.4318       0.0266  0.4584
# 1013.00  76    -47.0676  46.5693 -0.4983  -0.0000       0.0979  0.0979
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
