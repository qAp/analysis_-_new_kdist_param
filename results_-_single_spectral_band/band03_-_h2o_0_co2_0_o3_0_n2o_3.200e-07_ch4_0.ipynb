# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1d55451f-f288-40f1-b250-c1a85874cd4f">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 3
MOLECULE = {'n2o':3.2e-7}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
COLLEC_CLI = CLIENT.cliradnew.lw    
COLLEC_LBL = CLIENT.lblnew.bestfit_lw if len(MOLECULE) == 1 else CLIENT.lblnew.overlap_lw

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band03 {'n2o': 3.2e-07}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=COLLEC_CLI))
    dcli = pcli.modeldata_pymongo(collection=COLLEC_CLI, commits=['1013f91', 'de5d43e', '523cbb7'])
    
    if len(MOLECULE) == 1:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_wgt_flux=1)
    else:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=COLLEC_LBL))
    dlbl = plbl.modeldata_pymongo(collection=COLLEC_LBL, commits=['a22ab94', 'a06b618', '5014a19'])
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [3] {'n2o': 3.2e-07} mls
#                          Run parameters                          \
#                                  CLIRAD                  LBLNEW
# atmpro                 mls               mls
# band                   [3]               3a
# commitnumber           1013f91           a06b618
# conc                   -                 3.2e-07
# dv                     -                 0.001
# klin                   -                 2.22e-20
# molecule               {'n2o': 3.2e-07}  n2o
# ng_adju                -                 [0, 0]
# ng_refs                -                 [1, 2]
# nv                     -                 1000
# option_compute_btable  -                 0
# option_compute_ktable  -                 1
# option_wgt_flux        -                 1
# option_wgt_k           -                 1
# ref_pts                -                 [[1, 250], [500, 250]]
# tsfc                   294               294
# vmax                   -                 620
# vmin                   -                 540
# w_diffuse              -                 [[1.8], [1.66, 1.8]]
# wgt                    -                 [[0.9], [0.5, 0.95]]
#
#                                Fit parameters
#                                     (n2o, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [1, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.8,), (1.66, 1.8)]
# wgt                    [(0.9,), (0.5, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="dbf15b48-c443-489e-92ca-5b18edae4179"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.000    1     -35.0171  0.0000 -35.0171 -35.0643    0.0000 -35.0643 -35.0643
# 180.875  41    -35.3023  0.2769 -35.0254 -35.3507    0.2564 -35.0942 -35.3508
# 1013.000 76    -36.2354  2.6133 -33.6221 -36.2354    2.6075 -33.6279 -36.2354
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1      0.0000 -35.0643 -0.0472       0.0000 -0.0472
# 180.875  41     0.2565 -35.0944 -0.0485      -0.0204 -0.0689
# 1013.000 76     2.6071 -33.6284 -0.0000      -0.0062 -0.0062
# _____
# -----------------------------
# #### [3] {'n2o': 3.2e-07} saw
#                          Run parameters                          \
#                                  CLIRAD                  LBLNEW
# atmpro                 saw               saw
# band                   [3]               3a
# commitnumber           1013f91           5014a19
# conc                   -                 3.2e-07
# dv                     -                 0.001
# klin                   -                 2.22e-20
# molecule               {'n2o': 3.2e-07}  n2o
# ng_adju                -                 [0, 0]
# ng_refs                -                 [1, 2]
# nv                     -                 1000
# option_compute_btable  -                 0
# option_compute_ktable  -                 0
# option_wgt_flux        -                 1
# option_wgt_k           -                 1
# ref_pts                -                 [[1, 250], [500, 250]]
# tsfc                   257               257
# vmax                   -                 620
# vmin                   -                 540
# w_diffuse              -                 [[1.8], [1.66, 1.8]]
# wgt                    -                 [[0.9], [0.5, 0.95]]
#
#                                Fit parameters
#                                     (n2o, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [1, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.8,), (1.66, 1.8)]
# wgt                    [(0.9,), (0.5, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ff59bf86-b914-48b0-a6bc-0883af925946"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.00     1     -23.0301  0.0000 -23.0301 -23.0505    0.0000 -23.0505 -23.0505
# 299.75   46    -23.2964  0.4126 -22.8839 -23.3199    0.3908 -22.9290 -23.3200
# 1013.00  76    -23.5911  1.8703 -21.7209 -23.5911    1.8887 -21.7024 -23.5911
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1      0.0000 -23.0505 -0.0204       0.0000 -0.0204
# 299.75   46     0.3908 -22.9292 -0.0236      -0.0217 -0.0453
# 1013.00  76     1.8886 -21.7026 -0.0000       0.0183  0.0183
# _____
# -----------------------------
# #### [3] {'n2o': 3.2e-07} trp
#                          Run parameters                          \
#                                  CLIRAD                  LBLNEW
# atmpro                 trp               trp
# band                   [3]               3a
# commitnumber           1013f91           5014a19
# conc                   -                 3.2e-07
# dv                     -                 0.001
# klin                   -                 2.22e-20
# molecule               {'n2o': 3.2e-07}  n2o
# ng_adju                -                 [0, 0]
# ng_refs                -                 [1, 2]
# nv                     -                 1000
# option_compute_btable  -                 0
# option_compute_ktable  -                 0
# option_wgt_flux        -                 1
# option_wgt_k           -                 1
# ref_pts                -                 [[1, 250], [500, 250]]
# tsfc                   300               300
# vmax                   -                 620
# vmin                   -                 540
# w_diffuse              -                 [[1.8], [1.66, 1.8]]
# wgt                    -                 [[0.9], [0.5, 0.95]]
#
#                                Fit parameters
#                                     (n2o, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [1, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.8,), (1.66, 1.8)]
# wgt                    [(0.9,), (0.5, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="52869965-7988-4075-b6d5-2400720b3062"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.00     1     -37.0851  0.0000 -37.0851 -37.1404    0.0000 -37.1404 -37.1405
# 109.55   38    -37.2535  0.1480 -37.1055 -37.3127    0.1410 -37.1717 -37.3128
# 1013.00  76    -38.4917  2.6979 -35.7938 -38.4917    2.6872 -35.8046 -38.4917
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1      0.0000 -37.1405 -0.0554       0.0000 -0.0554
# 109.55   38     0.1410 -37.1719 -0.0594      -0.0071 -0.0664
# 1013.00  76     2.6866 -35.8051  0.0000      -0.0113 -0.0113
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
