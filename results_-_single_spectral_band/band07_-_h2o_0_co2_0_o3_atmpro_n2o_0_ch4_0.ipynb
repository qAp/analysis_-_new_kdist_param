# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="aa7ac036-273a-4ee8-b87a-3dc3e219c58b">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 7
MOLECULE = {'o3':'atmpro'}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
COLLEC_CLI = CLIENT.cliradnew.lw    
COLLEC_LBL = CLIENT.lblnew.bestfit_lw if len(MOLECULE) == 1 else CLIENT.lblnew.overlap_lw

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band07 {'o3': 'atmpro'}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=COLLEC_CLI))
    dcli = pcli.modeldata_pymongo(collection=COLLEC_CLI, commits=['1013f91', 'de5d43e', '523cbb7'])
    
    if len(MOLECULE) == 1:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_wgt_flux=1)
    else:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=COLLEC_LBL))
    dlbl = plbl.modeldata_pymongo(collection=COLLEC_LBL, commits=['a22ab94', 'a06b618', '5014a19'])
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [7] {'o3': 'atmpro'} mls
#                          Run parameters  \
#                                  CLIRAD
# atmpro                 mls
# band                   [7]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'o3': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                     \
#                                                             LBLNEW
# atmpro                 mls
# band                   5
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   2e-20
# molecule               o3
# ng_adju                [0, 0]
# ng_refs                [2, 5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [50, 250]]
# tsfc                   294
# vmax                   1100
# vmin                   980
# w_diffuse              [[1.6, 1.75], [1.55, 1.66, 1.7, 1.75, 1.8]]
# wgt                    [[0.35, 0.6], [0.5, 0.55, 0.7, 0.9, 1.0]]
#
#                                                     Fit parameters
#                                                            (o3, 5)
# atmpro                 mls
# band                   5
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   2e-20
# molecule               o3
# ng_adju                [0, 0]
# ng_refs                [2, 5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (50, 250)]
# tsfc                   294
# vmax                   1100
# vmin                   980
# w_diffuse              [(1.6, 1.75), (1.55, 1.66, 1.7, 1.75, 1.8)]
# wgt                    [(0.35, 0.6), (0.5, 0.55, 0.7, 0.9, 1.0)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6f93c9d4-8a45-4e63-b7db-4d5da99da35a"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.000    1     -23.0456  0.0000 -23.0456 -22.6521    0.0000 -22.6521 -22.6412
# 180.875  41    -27.7799  1.7684 -26.0115 -27.8842    1.8292 -26.0550 -27.8847
# 1013.000 76    -31.3542  4.3529 -27.0013 -31.3542    4.2923 -27.0619 -31.3542
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1     -0.0000 -22.6412  0.4044      -0.0000  0.4044
# 180.875  41     1.8323 -26.0524 -0.1048       0.0639 -0.0409
# 1013.000 76     4.2943 -27.0600 -0.0000      -0.0586 -0.0586
# _____
# -----------------------------
# #### [7] {'o3': 'atmpro'} saw
#                          Run parameters  \
#                                  CLIRAD
# atmpro                 saw
# band                   [7]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'o3': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                     \
#                                                             LBLNEW
# atmpro                 saw
# band                   5
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   2e-20
# molecule               o3
# ng_adju                [0, 0]
# ng_refs                [2, 5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  0
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [50, 250]]
# tsfc                   257
# vmax                   1100
# vmin                   980
# w_diffuse              [[1.6, 1.75], [1.55, 1.66, 1.7, 1.75, 1.8]]
# wgt                    [[0.35, 0.6], [0.5, 0.55, 0.7, 0.9, 1.0]]
#
#                                                     Fit parameters
#                                                            (o3, 5)
# atmpro                 mls
# band                   5
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   2e-20
# molecule               o3
# ng_adju                [0, 0]
# ng_refs                [2, 5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (50, 250)]
# tsfc                   294
# vmax                   1100
# vmin                   980
# w_diffuse              [(1.6, 1.75), (1.55, 1.66, 1.7, 1.75, 1.8)]
# wgt                    [(0.35, 0.6), (0.5, 0.55, 0.7, 0.9, 1.0)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="41d40791-9d02-4cd1-82ec-18df34b65a43"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.00     1     -10.9953  0.0000 -10.9953 -10.7113    0.0000 -10.7113 -10.7058
# 299.75   46    -14.4324  2.1040 -12.3284 -14.5009    2.2319 -12.2690 -14.5010
# 1013.00  76    -15.0514  2.8033 -12.2481 -15.0514    2.8838 -12.1676 -15.0514
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -0.0000 -10.7058  0.2896      -0.0000  0.2896
# 299.75   46     2.2346 -12.2664 -0.0686       0.1306  0.0620
# 1013.00  76     2.8861 -12.1653 -0.0000       0.0828  0.0828
# _____
# -----------------------------
# #### [7] {'o3': 'atmpro'} trp
#                          Run parameters  \
#                                  CLIRAD
# atmpro                 trp
# band                   [7]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'o3': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                     \
#                                                             LBLNEW
# atmpro                 trp
# band                   5
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   2e-20
# molecule               o3
# ng_adju                [0, 0]
# ng_refs                [2, 5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  0
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [50, 250]]
# tsfc                   300
# vmax                   1100
# vmin                   980
# w_diffuse              [[1.6, 1.75], [1.55, 1.66, 1.7, 1.75, 1.8]]
# wgt                    [[0.35, 0.6], [0.5, 0.55, 0.7, 0.9, 1.0]]
#
#                                                     Fit parameters
#                                                            (o3, 5)
# atmpro                 mls
# band                   5
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   2e-20
# molecule               o3
# ng_adju                [0, 0]
# ng_refs                [2, 5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (50, 250)]
# tsfc                   294
# vmax                   1100
# vmin                   980
# w_diffuse              [(1.6, 1.75), (1.55, 1.66, 1.7, 1.75, 1.8)]
# wgt                    [(0.35, 0.6), (0.5, 0.55, 0.7, 0.9, 1.0)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b195a834-6ba1-4f9b-a05f-7780168bdc9c"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.00     1     -27.0116  0.0000 -27.0116 -26.7748    0.0000 -26.7748 -26.7647
# 109.55   38    -31.6059  1.2180 -30.3879 -31.8030    1.2767 -30.5262 -31.8037
# 1013.00  76    -34.7286  3.5746 -31.1540 -34.7286    3.4338 -31.2949 -34.7286
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -0.0000 -26.7647  0.2469      -0.0000  0.2469
# 109.55   38     1.2796 -30.5241 -0.1978       0.0616 -0.1362
# 1013.00  76     3.4355 -31.2932  0.0000      -0.1392 -0.1392
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
