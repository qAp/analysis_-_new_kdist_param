# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6c7770c0-5f6e-41db-9361-0daf1e7b7997">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 3
MOLECULE = {'h2o':'atmpro', 'co2':400e-6, 'n2o':3.2e-07}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
COLLEC_CLI = CLIENT.cliradnew.lw    
COLLEC_LBL = CLIENT.lblnew.bestfit_lw if len(MOLECULE) == 1 else CLIENT.lblnew.overlap_lw

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band03 {'h2o': 'atmpro', 'co2': 0.0004, 'n2o': 3.2e-07}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=COLLEC_CLI))
    dcli = pcli.modeldata_pymongo(collection=COLLEC_CLI, commits=['1013f91', 'de5d43e', '523cbb7'])
    
    if len(MOLECULE) == 1:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_flux_wgt=1)
    else:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=COLLEC_LBL))
    dlbl = plbl.modeldata_pymongo(collection=COLLEC_LBL, commits=['5014a19'])
        
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [3] {'co2': 0.0004, 'h2o': 'atmpro', 'n2o': 3.2e-07} mls
#                                                          Run parameters  \
#                                                                  CLIRAD
# atmpro                 mls
# band                   [3]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro', 'n2o': 3.2e-07}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                          \
#                                                                  LBLNEW
# atmpro                 mls
# band                   3a
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'co2': 0.0004, 'n2o': 3.2e-07}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                        Fit parameters  \
#                                                             (h2o, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0, 0]
# ng_refs                [2, 6]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(10, 250), (600, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)]
# wgt                    [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]
#
#                                                                                  \
#                                                                       (co2, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.37556e-24
# molecule               co2
# ng_adju                [0, 0, 0]
# ng_refs                [3, 2, 4]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)]
# wgt                    [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]
#
#
#                                     (n2o, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [1, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.8,), (1.66, 1.8)]
# wgt                    [(0.9,), (0.5, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="9e764d1e-8e4e-4321-ac06-f39a1eeac1ff"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.000    1     -24.8661  0.0000  -24.8661 -25.2155    0.0000  -25.2155
# 180.875  41    -25.3299  1.6719  -23.6580 -25.6805    1.7414  -23.9390
# 1013.000 76    -36.2354  34.6882 -1.5472  -36.2354    34.3532 -1.8822
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1     -25.1751  0.0000  -25.1751 -0.3091       0.0000 -0.3091
# 180.875  41    -25.6446  1.7539  -23.8907 -0.3146       0.0819 -0.2327
# 1013.000 76    -36.2354  34.3909 -1.8445  -0.0000      -0.2972 -0.2972
# _____
# -----------------------------
# #### [3] {'co2': 0.0004, 'h2o': 'atmpro', 'n2o': 3.2e-07} saw
#                                                          Run parameters  \
#                                                                  CLIRAD
# atmpro                 saw
# band                   [3]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro', 'n2o': 3.2e-07}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                          \
#                                                                  LBLNEW
# atmpro                 saw
# band                   3a
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'co2': 0.0004, 'n2o': 3.2e-07}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                        Fit parameters  \
#                                                             (h2o, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0, 0]
# ng_refs                [2, 6]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(10, 250), (600, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)]
# wgt                    [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]
#
#                                                                                  \
#                                                                       (co2, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.37556e-24
# molecule               co2
# ng_adju                [0, 0, 0]
# ng_refs                [3, 2, 4]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)]
# wgt                    [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]
#
#
#                                     (n2o, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [1, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.8,), (1.66, 1.8)]
# wgt                    [(0.9,), (0.5, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="55523494-690a-4090-909e-9e71435f5e24"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.00     1     -19.7044  0.0000  -19.7044 -19.8010    0.0000  -19.8010
# 299.75   46    -20.4500  2.4623  -17.9877 -20.5562    2.5784  -17.9778
# 1013.00  76    -23.5911  17.7218 -5.8693  -23.5911    17.1426 -6.4485
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -19.7789  0.0000  -19.7789 -0.0746       0.0000 -0.0746
# 299.75   46    -20.5386  2.5947  -17.9439 -0.0886       0.1324  0.0438
# 1013.00  76    -23.5911  17.1985 -6.3926  -0.0000      -0.5233 -0.5233
# _____
# -----------------------------
# #### [3] {'co2': 0.0004, 'h2o': 'atmpro', 'n2o': 3.2e-07} trp
#                                                          Run parameters  \
#                                                                  CLIRAD
# atmpro                 trp
# band                   [3]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro', 'n2o': 3.2e-07}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                          \
#                                                                  LBLNEW
# atmpro                 trp
# band                   3a
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'co2': 0.0004, 'n2o': 3.2e-07}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                        Fit parameters  \
#                                                             (h2o, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0, 0]
# ng_refs                [2, 6]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(10, 250), (600, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.9, 1.7), (1.4, 1.4, 1.4, 1.55, 1.6, 1.66)]
# wgt                    [(0.7, 0.7), (0.7, 0.5, 0.5, 0.5, 0.5, 0.5)]
#
#                                                                                  \
#                                                                       (co2, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.37556e-24
# molecule               co2
# ng_adju                [0, 0, 0]
# ng_refs                [3, 2, 4]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.6, 1.6, 1.7), (1.75, 1.75), (1.55, 1.55, 1.6, 1.85)]
# wgt                    [(0.7, 0.3, 0.7), (0.7, 0.6), (0.4, 0.5, 0.8, 0.95)]
#
#
#                                     (n2o, 3a)
# atmpro                 mls
# band                   3a
# commitnumber           a06b618
# conc                   3.2e-07
# dv                     0.001
# klin                   2.22e-20
# molecule               n2o
# ng_adju                [0, 0]
# ng_refs                [1, 2]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (500, 250)]
# tsfc                   294
# vmax                   620
# vmin                   540
# w_diffuse              [(1.8,), (1.66, 1.8)]
# wgt                    [(0.9,), (0.5, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="56c7cdaa-cead-4483-86ed-4e80555b0706"></div>
# </div>
#                     CRD                   WGT igg=10                    \
#                    flug     fldg    fnetg       flug     fldg    fnetg
# pressure level
# 0.00     1     -25.1537  0.0000  -25.1537 -25.4994    0.0000  -25.4994
# 109.55   38    -25.2365  0.8097  -24.4268 -25.5676    0.8219  -24.7456
# 1013.00  76    -38.4917  37.3253 -1.1664  -38.4917    37.0985 -1.3932
#
#                  CLIRAD                   CLIRAD - CRD
#                    flug     fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -25.4553  0.0000  -25.4553 -0.3015       0.0000 -0.3015
# 109.55   38    -25.5251  0.8291  -24.6960 -0.2886       0.0194 -0.2692
# 1013.00  76    -38.4917  37.1218 -1.3699   0.0000      -0.2035 -0.2035
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
