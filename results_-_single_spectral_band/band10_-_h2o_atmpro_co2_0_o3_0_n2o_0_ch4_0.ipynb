# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a10cb360-cd0f-4ec9-a5a4-742319cebdd1">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 10
MOLECULE = {'h2o':'atmpro'}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
COLLEC_CLI = CLIENT.cliradnew.lw    
COLLEC_LBL = CLIENT.lblnew.bestfit_lw if len(MOLECULE) == 1 else CLIENT.lblnew.overlap_lw

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band10 {'h2o': 'atmpro'}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=COLLEC_CLI))
    dcli = pcli.modeldata_pymongo(collection=COLLEC_CLI, commits=['1013f91', 'de5d43e'])
    
    if len(MOLECULE) == 1:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_wgt_flux=1)
    else:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=COLLEC_LBL))
    dlbl = plbl.modeldata_pymongo(collection=COLLEC_LBL, commits=['a06b618', '5014a19'])
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [10] {'h2o': 'atmpro'} mls
#                           Run parameters  \
#                                   CLIRAD
# atmpro                 mls
# band                   [10]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                                \
#                                                                        LBLNEW
# atmpro                 mls
# band                   8
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0, -1, 0]
# ng_refs                [3, 2, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [10, 250], [500, 250]]
# tsfc                   294
# vmax                   1900
# vmin                   1380
# w_diffuse              [[1.66, 1.66, 1.66], [1.66, 1.66], [1.66, 1.66, 1.66]]
# wgt                    [[0.55, 0.55, 0.85], [0.85, 0.85], [0, 0.3, 0.55]]
#
#                                                                Fit parameters
#                                                                      (h2o, 8)
# atmpro                 mls
# band                   8
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0, -1, 0]
# ng_refs                [3, 2, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   1900
# vmin                   1380
# w_diffuse              [(1.66, 1.66, 1.66), (1.66, 1.66), (1.66, 1.66, 1.66)]
# wgt                    [(0.55, 0.55, 0.85), (0.85, 0.85), (0, 0.3, 0.55)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e1457b6d-ac09-4e12-94d6-271024636455"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug     fldg   fnetg       flug     fldg   fnetg     flug
# pressure level
# 0.000    1     -7.2920   0.0000  -7.2920 -7.1659     0.0000  -7.1659 -7.1603
# 180.875  41    -7.3238   0.1886  -7.1352 -7.2007     0.1948  -7.0059 -7.1953
# 1013.000 76    -30.7296  30.3724 -0.3572 -30.7296    30.3882 -0.3415 -30.7296
#
#                                 CLIRAD - CRD
#                    fldg   fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1     -0.0000  -7.1603  0.1317      -0.0000  0.1317
# 180.875  41     0.1951  -7.0002  0.1285       0.0065  0.1350
# 1013.000 76     30.3855 -0.3441 -0.0000       0.0131  0.0131
# _____
# -----------------------------
# #### [10] {'h2o': 'atmpro'} saw
#                           Run parameters  \
#                                   CLIRAD
# atmpro                 saw
# band                   [10]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                                \
#                                                                        LBLNEW
# atmpro                 saw
# band                   8
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0, -1, 0]
# ng_refs                [3, 2, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  0
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [10, 250], [500, 250]]
# tsfc                   257
# vmax                   1900
# vmin                   1380
# w_diffuse              [[1.66, 1.66, 1.66], [1.66, 1.66], [1.66, 1.66, 1.66]]
# wgt                    [[0.55, 0.55, 0.85], [0.85, 0.85], [0, 0.3, 0.55]]
#
#                                                                Fit parameters
#                                                                      (h2o, 8)
# atmpro                 mls
# band                   8
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0, -1, 0]
# ng_refs                [3, 2, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   1900
# vmin                   1380
# w_diffuse              [(1.66, 1.66, 1.66), (1.66, 1.66), (1.66, 1.66, 1.66)]
# wgt                    [(0.55, 0.55, 0.85), (0.85, 0.85), (0, 0.3, 0.55)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7aa93fb9-2173-4f65-a389-1a542e2a49dc"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug     fldg   fnetg       flug     fldg   fnetg     flug
# pressure level
# 0.00     1     -4.8838   0.0000  -4.8838 -4.8907     0.0000  -4.8907 -4.8885
# 299.75   46    -5.0729   0.4571  -4.6157 -5.0791     0.5072  -4.5718 -5.0769
# 1013.00  76    -10.1814  10.2098  0.0283 -10.1814    10.2457  0.0643 -10.1814
#
#                                 CLIRAD - CRD
#                    fldg   fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -0.0000  -4.8885 -0.0047      -0.0000 -0.0047
# 299.75   46     0.5076  -4.5693 -0.0040       0.0505  0.0465
# 1013.00  76     10.2458  0.0644  0.0000       0.0361  0.0361
# _____
# -----------------------------
# #### [10] {'h2o': 'atmpro'} trp
#                           Run parameters  \
#                                   CLIRAD
# atmpro                 trp
# band                   [10]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                                                \
#                                                                        LBLNEW
# atmpro                 trp
# band                   8
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0, -1, 0]
# ng_refs                [3, 2, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  0
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [[1, 250], [10, 250], [500, 250]]
# tsfc                   300
# vmax                   1900
# vmin                   1380
# w_diffuse              [[1.66, 1.66, 1.66], [1.66, 1.66], [1.66, 1.66, 1.66]]
# wgt                    [[0.55, 0.55, 0.85], [0.85, 0.85], [0, 0.3, 0.55]]
#
#                                                                Fit parameters
#                                                                      (h2o, 8)
# atmpro                 mls
# band                   8
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   0
# molecule               h2o
# ng_adju                [0, -1, 0]
# ng_refs                [3, 2, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (10, 250), (500, 250)]
# tsfc                   294
# vmax                   1900
# vmin                   1380
# w_diffuse              [(1.66, 1.66, 1.66), (1.66, 1.66), (1.66, 1.66, 1.66)]
# wgt                    [(0.55, 0.55, 0.85), (0.85, 0.85), (0, 0.3, 0.55)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b8b1caf8-fe82-47e5-81ba-05c086ee2970"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug     fldg   fnetg       flug     fldg   fnetg     flug
# pressure level
# 0.00     1     -7.7150   0.0000  -7.7150 -7.5799     0.0000  -7.5799 -7.5744
# 109.55   38    -7.6984   0.0549  -7.6435 -7.5587     0.0556  -7.5030 -7.5532
# 1013.00  76    -35.8550  35.2698 -0.5852 -35.8550    35.2830 -0.5720 -35.8550
#
#                                 CLIRAD - CRD
#                    fldg   fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -0.0000  -7.5744  0.1406      -0.0000  0.1406
# 109.55   38     0.0557  -7.4974  0.1452       0.0008  0.1460
# 1013.00  76     35.2819 -0.5731  0.0000       0.0121  0.0121
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
