# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1aa1ede1-3718-473b-8736-c323c104584b">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 8
MOLECULE = {'h2o':'atmpro'}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
COLLEC_CLI = CLIENT.cliradnew.lw    
COLLEC_LBL = CLIENT.lblnew.bestfit_lw if len(MOLECULE) == 1 else CLIENT.lblnew.overlap_lw

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band08 {'h2o': 'atmpro'}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=COLLEC_CLI))
    dcli = pcli.modeldata_pymongo(collection=COLLEC_CLI, commits=['1013f91', 'de5d43e'])
    
    if len(MOLECULE) == 1:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_wgt_flux=1)
    else:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=COLLEC_LBL))
    dlbl = plbl.modeldata_pymongo(collection=COLLEC_LBL, commits=['a06b618', '5014a19'])
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [8] {'h2o': 'atmpro'} mls
#                           Run parameters                            \
#                                   CLIRAD                    LBLNEW
# atmpro                 mls                mls
# band                   [8]                6
# commitnumber           1013f91            a06b618
# conc                   -                  -
# dv                     -                  0.001
# klin                   -                  5e-25
# molecule               {'h2o': 'atmpro'}  h2o
# ng_adju                -                  [0]
# ng_refs                -                  [4]
# nv                     -                  1000
# option_compute_btable  -                  0
# option_compute_ktable  -                  1
# option_wgt_flux        -                  1
# option_wgt_k           -                  1
# ref_pts                -                  [[600, 250]]
# tsfc                   294                294
# vmax                   -                  1215
# vmin                   -                  1100
# w_diffuse              -                  [[1.66, 1.66, 1.7, 1.8]]
# wgt                    -                  [[0.3, 0.45, 0.6, 0.95]]
#
#                                  Fit parameters
#                                        (h2o, 6)
# atmpro                 mls
# band                   6
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   5e-25
# molecule               h2o
# ng_adju                [0]
# ng_refs                [4]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(600, 250)]
# tsfc                   294
# vmax                   1215
# vmin                   1100
# w_diffuse              [(1.66, 1.66, 1.7, 1.8)]
# wgt                    [(0.3, 0.45, 0.6, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="064983ce-97d7-4cd8-83da-2f1868ef7c9c"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.000    1     -21.7810  0.0000 -21.7810 -21.8904    0.0000 -21.8904 -21.8808
# 180.875  41    -21.7819  0.0008 -21.7811 -21.8912    0.0004 -21.8908 -21.8815
# 1013.000 76    -23.2697  6.2938 -16.9758 -23.2697    6.1110 -17.1586 -23.2697
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1     -0.0000 -21.8808 -0.0998      -0.0000 -0.0998
# 180.875  41     0.0004 -21.8812 -0.0997      -0.0004 -0.1001
# 1013.000 76     6.1535 -17.1162 -0.0000      -0.1404 -0.1404
# _____
# -----------------------------
# #### [8] {'h2o': 'atmpro'} saw
#                           Run parameters                            \
#                                   CLIRAD                    LBLNEW
# atmpro                 saw                saw
# band                   [8]                6
# commitnumber           1013f91            5014a19
# conc                   -                  -
# dv                     -                  0.001
# klin                   -                  5e-25
# molecule               {'h2o': 'atmpro'}  h2o
# ng_adju                -                  [0]
# ng_refs                -                  [4]
# nv                     -                  1000
# option_compute_btable  -                  0
# option_compute_ktable  -                  0
# option_wgt_flux        -                  1
# option_wgt_k           -                  1
# ref_pts                -                  [[600, 250]]
# tsfc                   257                257
# vmax                   -                  1215
# vmin                   -                  1100
# w_diffuse              -                  [[1.66, 1.66, 1.7, 1.8]]
# wgt                    -                  [[0.3, 0.45, 0.6, 0.95]]
#
#                                  Fit parameters
#                                        (h2o, 6)
# atmpro                 mls
# band                   6
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   5e-25
# molecule               h2o
# ng_adju                [0]
# ng_refs                [4]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(600, 250)]
# tsfc                   294
# vmax                   1215
# vmin                   1100
# w_diffuse              [(1.66, 1.66, 1.7, 1.8)]
# wgt                    [(0.3, 0.45, 0.6, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a3c2b733-b427-480e-afc2-e7352052c0c7"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.00     1     -10.2139  0.0000 -10.2139 -10.2292    0.0000 -10.2292 -10.2284
# 299.75   46    -10.2165  0.0019 -10.2145 -10.2311    0.0011 -10.2300 -10.2303
# 1013.00  76    -10.2971  0.8403 -9.4568  -10.2971    0.7563 -9.5408  -10.2971
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -0.0000 -10.2284 -0.0145      -0.0000 -0.0145
# 299.75   46     0.0011 -10.2292 -0.0139      -0.0008 -0.0147
# 1013.00  76     0.7615 -9.5357   0.0000      -0.0789 -0.0789
# _____
# -----------------------------
# #### [8] {'h2o': 'atmpro'} trp
#                           Run parameters                            \
#                                   CLIRAD                    LBLNEW
# atmpro                 trp                trp
# band                   [8]                6
# commitnumber           1013f91            5014a19
# conc                   -                  -
# dv                     -                  0.001
# klin                   -                  5e-25
# molecule               {'h2o': 'atmpro'}  h2o
# ng_adju                -                  [0]
# ng_refs                -                  [4]
# nv                     -                  1000
# option_compute_btable  -                  0
# option_compute_ktable  -                  0
# option_wgt_flux        -                  1
# option_wgt_k           -                  1
# ref_pts                -                  [[600, 250]]
# tsfc                   300                300
# vmax                   -                  1215
# vmin                   -                  1100
# w_diffuse              -                  [[1.66, 1.66, 1.7, 1.8]]
# wgt                    -                  [[0.3, 0.45, 0.6, 0.95]]
#
#                                  Fit parameters
#                                        (h2o, 6)
# atmpro                 mls
# band                   6
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   5e-25
# molecule               h2o
# ng_adju                [0]
# ng_refs                [4]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(600, 250)]
# tsfc                   294
# vmax                   1215
# vmin                   1100
# w_diffuse              [(1.66, 1.66, 1.7, 1.8)]
# wgt                    [(0.3, 0.45, 0.6, 0.95)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="f83284ec-2ebe-4f65-a102-89be94e22b54"></div>
# </div>
#                     CRD                  WGT igg=10                    CLIRAD  \
#                    flug    fldg    fnetg       flug    fldg    fnetg     flug
# pressure level
# 0.00     1     -23.8147  0.0000 -23.8147 -23.9397    0.0000 -23.9397 -23.9253
# 109.55   38    -23.8151  0.0003 -23.8148 -23.9400    0.0001 -23.9399 -23.9256
# 1013.00  76    -26.0652  8.3707 -17.6945 -26.0652    8.3370 -17.7282 -26.0652
#
#                                 CLIRAD - CRD
#                   fldg    fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1     -0.0000 -23.9253 -0.1106      -0.0000 -0.1106
# 109.55   38     0.0001 -23.9255 -0.1105      -0.0002 -0.1107
# 1013.00  76     8.3858 -17.6794  0.0000       0.0150  0.0150
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
