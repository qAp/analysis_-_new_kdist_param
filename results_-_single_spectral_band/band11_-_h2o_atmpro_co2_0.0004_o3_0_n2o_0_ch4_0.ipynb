# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import pprint
import pymongo
from bokeh.io import output_notebook
from climatools.cliradlw.cliradlw_latest import *
from climatools.html.html import *
from climatools.spectrum import *
from climatools.atm import *
output_notebook()
pd.set_option('max_colwidth', -1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2b0b5610-dc21-4f5e-8829-76cb4b960f98">Loading BokehJS ...</span>
#     </div>

# %%
CLIENT = pymongo.MongoClient(host='localhost', port=27017)

# %%
BAND = 11
MOLECULE = {'h2o':'atmpro', 'co2':400e-6}
NV, DV = 1000, .001
ATMPRO = dict(mls=294, saw=257, trp=300)

# %%
atmcomp = AtmComposition.cliradlw_nongreys()
for gas, conc in MOLECULE.items(): atmcomp.gasconcs[gas] = conc
atmcomp.gasinbands = {BAND: list(MOLECULE.keys())}

# %%
COLLEC_CLI = CLIENT.cliradnew.lw    
COLLEC_LBL = CLIENT.lblnew.bestfit_lw if len(MOLECULE) == 1 else CLIENT.lblnew.overlap_lw

# %%
display.display(display.Markdown(f'''# Band{BAND:02d} {MOLECULE}'''))
# Out:
# # Band11 {'h2o': 'atmpro', 'co2': 0.0004}

# %%
for atmpro in ATMPRO.keys():
    pcli = atmcomp.to_cliradparam(atmpro=atmpro, tsfc=ATMPRO[atmpro])
    #print(pcli.avail_commits(collection=COLLEC_CLI))
    dcli = pcli.modeldata_pymongo(collection=COLLEC_CLI, commits=['1013f91', 'de5d43e'])
    
    if len(MOLECULE) == 1:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV, option_wgt_flux=1)
    else:
        plbls = atmcomp.to_lblnewparam(atmpro=atmpro, tsfc=ATMPRO[atmpro], nv=NV, dv=DV)
    plbl = plbls[0]
    #print(plbl.avail_commits(collection=COLLEC_LBL))
    dlbl = plbl.modeldata_pymongo(collection=COLLEC_LBL, commits=['5014a19'])
    show_results(dlbl=dlbl, dcli=dcli, atmpro=atmpro)
# Out:
# -----------------------------
# #### [11] {'co2': 0.0004, 'h2o': 'atmpro'} mls
#                                          Run parameters  \
#                                                  CLIRAD
# atmpro                 mls
# band                   [11]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                          \
#                                                  LBLNEW
# atmpro                 mls
# band                   9
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'co2': 0.0004}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   294
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                          Fit parameters  \
#                                                (h2o, 9)
# atmpro                 mls
# band                   9
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   1e-24
# molecule               h2o
# ng_adju                [0]
# ng_refs                [5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(500, 250)]
# tsfc                   294
# vmax                   3000
# vmin                   1900
# w_diffuse              [(1.66, 1.66, 1.66, 1.66, 1.66)]
# wgt                    [(0.4, 0.4, 0.5, 0.55, 0.85)]
#
#
#                                                       (co2, 9)
# atmpro                 mls
# band                   9
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.5e-24
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [3, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (50, 250)]
# tsfc                   294
# vmax                   3000
# vmin                   1900
# w_diffuse              [(1.66, 1.66, 1.75), (1.75, 1.6, 1.85)]
# wgt                    [(0.7, 0.8, 0.7), (0.8, 0.7, 0.8)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="71970f71-820e-4f19-a1c1-30b57f3d64ba"></div>
# </div>
#                    CRD                 WGT igg=10                  CLIRAD  \
#                   flug    fldg   fnetg       flug    fldg   fnetg    flug
# pressure level
# 0.000    1     -4.0877  0.0000 -4.0877 -4.0271     0.0000 -4.0271 -4.0220
# 180.875  41    -4.0713  0.0170 -4.0543 -4.0086     0.0192 -3.9894 -4.0033
# 1013.000 76    -6.6255  4.0614 -2.5640 -6.6255     4.0628 -2.5626 -6.6255
#
#                                CLIRAD - CRD
#                   fldg   fnetg         flug    fldg   fnetg
# pressure level
# 0.000    1      0.0000 -4.0220  0.0657       0.0000  0.0657
# 180.875  41     0.0192 -3.9841  0.0680       0.0022  0.0702
# 1013.000 76     4.0689 -2.5566  0.0000       0.0075  0.0075
# _____
# -----------------------------
# #### [11] {'co2': 0.0004, 'h2o': 'atmpro'} saw
#                                          Run parameters  \
#                                                  CLIRAD
# atmpro                 saw
# band                   [11]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                          \
#                                                  LBLNEW
# atmpro                 saw
# band                   9
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'co2': 0.0004}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   257
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                          Fit parameters  \
#                                                (h2o, 9)
# atmpro                 mls
# band                   9
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   1e-24
# molecule               h2o
# ng_adju                [0]
# ng_refs                [5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(500, 250)]
# tsfc                   294
# vmax                   3000
# vmin                   1900
# w_diffuse              [(1.66, 1.66, 1.66, 1.66, 1.66)]
# wgt                    [(0.4, 0.4, 0.5, 0.55, 0.85)]
#
#
#                                                       (co2, 9)
# atmpro                 mls
# band                   9
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.5e-24
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [3, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (50, 250)]
# tsfc                   294
# vmax                   3000
# vmin                   1900
# w_diffuse              [(1.66, 1.66, 1.75), (1.75, 1.6, 1.85)]
# wgt                    [(0.7, 0.8, 0.7), (0.8, 0.7, 0.8)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="eed255c3-fca4-4c61-a2d4-d1377cec9df5"></div>
# </div>
#                    CRD                 WGT igg=10                  CLIRAD  \
#                   flug    fldg   fnetg       flug    fldg   fnetg    flug
# pressure level
# 0.00     1     -1.1649  0.0000 -1.1649 -1.1468     0.0000 -1.1468 -1.1461
# 299.75   46    -1.1791  0.0211 -1.1579 -1.1668     0.0244 -1.1425 -1.1660
# 1013.00  76    -1.4669  0.6674 -0.7995 -1.4669     0.6701 -0.7968 -1.4669
#
#                                CLIRAD - CRD
#                   fldg   fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1      0.0000 -1.1461  0.0189       0.0000  0.0189
# 299.75   46     0.0244 -1.1416  0.0130       0.0033  0.0163
# 1013.00  76     0.6709 -0.7960 -0.0000       0.0035  0.0035
# _____
# -----------------------------
# #### [11] {'co2': 0.0004, 'h2o': 'atmpro'} trp
#                                          Run parameters  \
#                                                  CLIRAD
# atmpro                 trp
# band                   [11]
# commitnumber           1013f91
# conc                   -
# dv                     -
# klin                   -
# molecule               {'co2': 0.0004, 'h2o': 'atmpro'}
# ng_adju                -
# ng_refs                -
# nv                     -
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                                          \
#                                                  LBLNEW
# atmpro                 trp
# band                   9
# commitnumber           5014a19
# conc                   -
# dv                     0.001
# klin                   -
# molecule               {'h2o': 'atmpro', 'co2': 0.0004}
# ng_adju                -
# ng_refs                -
# nv                     1000
# option_compute_btable  -
# option_compute_ktable  -
# option_wgt_flux        -
# option_wgt_k           -
# ref_pts                -
# tsfc                   300
# vmax                   -
# vmin                   -
# w_diffuse              -
# wgt                    -
#
#                                          Fit parameters  \
#                                                (h2o, 9)
# atmpro                 mls
# band                   9
# commitnumber           a06b618
# conc                   -
# dv                     0.001
# klin                   1e-24
# molecule               h2o
# ng_adju                [0]
# ng_refs                [5]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(500, 250)]
# tsfc                   294
# vmax                   3000
# vmin                   1900
# w_diffuse              [(1.66, 1.66, 1.66, 1.66, 1.66)]
# wgt                    [(0.4, 0.4, 0.5, 0.55, 0.85)]
#
#
#                                                       (co2, 9)
# atmpro                 mls
# band                   9
# commitnumber           a06b618
# conc                   0.0004
# dv                     0.001
# klin                   6.5e-24
# molecule               co2
# ng_adju                [0, 0]
# ng_refs                [3, 3]
# nv                     1000
# option_compute_btable  0
# option_compute_ktable  1
# option_wgt_flux        1
# option_wgt_k           1
# ref_pts                [(1, 250), (50, 250)]
# tsfc                   294
# vmax                   3000
# vmin                   1900
# w_diffuse              [(1.66, 1.66, 1.75), (1.75, 1.6, 1.85)]
# wgt                    [(0.7, 0.8, 0.7), (0.8, 0.7, 0.8)]
# <div class="bk-root">
#     <div class="bk-plotdiv" id="51263346-5028-461c-8066-baa57c9d1ebc"></div>
# </div>
#                    CRD                 WGT igg=10                  CLIRAD  \
#                   flug    fldg   fnetg       flug    fldg   fnetg    flug
# pressure level
# 0.00     1     -4.7060  0.0000 -4.7060 -4.5992     0.0000 -4.5992 -4.5924
# 109.55   38    -4.6777  0.0051 -4.6726 -4.5644     0.0052 -4.5592 -4.5574
# 1013.00  76    -8.1851  5.1948 -2.9903 -8.1851     5.2520 -2.9331 -8.1851
#
#                                CLIRAD - CRD
#                   fldg   fnetg         flug    fldg   fnetg
# pressure level
# 0.00     1      0.0000 -4.5924  0.1136       0.0000  0.1136
# 109.55   38     0.0052 -4.5522  0.1203       0.0001  0.1204
# 1013.00  76     5.2586 -2.9266 -0.0000       0.0637  0.0637
# _____

# %% [markdown]
# # fin

# %%
display.HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
